# %%
# Clone your GitHub repository
# !git clone https://github.com/ETHARTIC/Class-activities.git
# Out:
# Cloning into 'Class-activities'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 41 (delta 7), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 96.62 KiB | 5.68 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %%
from pathlib import Path
import pandas as pd

# The base directory will now be the cloned GitHub repository
# Assuming the repository clones into '/content/Class-activities'
BASE_REPO_DIR = Path("/content/Class-activities")

# Construct the full path to the CSV file within the cloned repository
archivo = "cantidad_de_residuos_en_la_estacion_de_transferencia_2023.csv"
ruta_csv = BASE_REPO_DIR / "Actividades-de-clase" / "data" / archivo

# 3. Verificar que el archivo realmente existe antes de cargarlo
if not ruta_csv.exists():
    raise FileNotFoundError(f"No se encontró el archivo en: {ruta_csv}. Por favor, verifica la ruta dentro del repositorio clonado.")

# 4. Cargar el archivo CSV
df = pd.read_csv(ruta_csv)

# 5. Inspección inicial de los datos
print(f"--- Archivo cargado exitosamente desde: {ruta_csv.name} ---")
print(df.info())
print("\nPrimeras 5 filas:")
print(df.head())

## 5.1. Dimensiones y estructura de los datos (Equivalente a str(df))
df.info()
# Nota: df.shape te da exactamente las dimensiones (filas, columnas) -> (1222, 41)
df.shape

# 5.2. Filas únicas: detectando la columna que contiene el ID (Equivalente a length(unique(...)))
df["matricula_letra"].nunique()

# 5.3 Datos faltantes

df.isnull().sum()  # Conteo de NA por columna
(df == "").sum()   # Falsos nulos (cadenas vacías)

## 5.4 Duplicados
df.duplicated().sum() # Cantidad de filas exactamente iguales
# Out:
# --- Archivo cargado exitosamente desde: cantidad_de_residuos_en_la_estacion_de_transferencia_2023.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222 entries, 0 to 1221
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pesada                 1222 non-null   int64
#  1   fecha_dia              1222 non-null   object
#  2   fecha                  1222 non-null   object
#  3   matricula_letra        1222 non-null   object
#  4   tipo_residuo           1222 non-null   int64
#  5   tipo_residuo_desc      1222 non-null   object
#  6   subtipo_residuo        1222 non-null   int64
#  7   subtipo_residuo_desc   1222 non-null   object
#  8   peso_neto              1222 non-null   int64
#  9   peso_bruto             1222 non-null   int64
#  10  tara                   1222 non-null   int64
#  11  balanza                1222 non-null   int64
#  12  medio_transp           1222 non-null   int64
#  13  medio_transp_desc      1222 non-null   object
#  14  trayecto               0 non-null      float64
#  15  trayecto_desc          0 non-null      float64
#  16  tipo_recorrido         0 non-null      float64
#  17  tipo_recorrido_desc    0 non-null      float64
#  18  tipo_volcado_desc      1222 non-null   object
#  19  nomenclatura_circuito  0 non-null      float64
#  20  municipio              0 non-null      float64
#  21  lugar_salida           0 non-null      float64
#  22  lugar_salida_desc      0 non-null      float64
#  23  permiso                0 non-null      float64
#  24  nro_permiso            394 non-null    float64
#  25  permiso_id             394 non-null    float64
#  26  tipo_permiso           394 non-null    float64
#  27  tipo_permiso_desc      394 non-null    object
#  28  peso_autorizado        0 non-null      float64
#  29  destino_volcado        1222 non-null   int64
#  30  destino_volcado_desc   1222 non-null   object
#  31  tipo_pesada            1222 non-null   int64
#  32  tipo_pesada_desc       1222 non-null   object
#  33  basura_propia          1222 non-null   object
#  34  fmod                   1222 non-null   object
#  35  viaje_fecha            785 non-null    object
#  36  fecha_tara             1222 non-null   object
#  37  sitio                  1222 non-null   int64
#  38  sitio_desc             1222 non-null   object
#  39  tipo_movimiento        1222 non-null   int64
#  40  tipo_movimiento_desc   1222 non-null   object
# dtypes: float64(13), int64(12), object(16)
# memory usage: 391.6+ KB
# None
#
# Primeras 5 filas:
#     pesada       fecha_dia           fecha matricula_letra  tipo_residuo  \
# 0  3996241  30/11/23 00:00  30/11/23 08:28             SIM             1
# 1  3996243  30/11/23 00:00  30/11/23 08:30             SIM             1
# 2  3996253  30/11/23 00:00  30/11/23 08:36             SIM             1
# 3  3996276  30/11/23 00:00  30/11/23 08:56             SIM             1
# 4  3996298  30/11/23 00:00  30/11/23 09:21             SIM             1
#
#    tipo_residuo_desc  subtipo_residuo       subtipo_residuo_desc  peso_neto  \
# 0  TIPO DOMICILIARIO                1  ASIMILABLE A DOMICILIARIO      11590
# 1  TIPO DOMICILIARIO                1  ASIMILABLE A DOMICILIARIO       8660
# 2  TIPO DOMICILIARIO                1  ASIMILABLE A DOMICILIARIO       6090
# 3  TIPO DOMICILIARIO                1  ASIMILABLE A DOMICILIARIO       7920
# 4  TIPO DOMICILIARIO                1  ASIMILABLE A DOMICILIARIO       9740
#
#    peso_bruto  ...  tipo_pesada  tipo_pesada_desc  basura_propia  \
# 0       28450  ...            1        AUTOMATICA             NO
# 1       26070  ...            1        AUTOMATICA             NO
# 2       25020  ...            1        AUTOMATICA             NO
# 3       24720  ...            1        AUTOMATICA             NO
# 4       26890  ...            1        AUTOMATICA             NO
#
#              fmod     viaje_fecha      fecha_tara  sitio  sitio_desc  \
# 0  16/01/24 10:41  29/11/23 00:00  30/11/23 08:39      2        ETRA
# 1  16/01/24 10:41  29/11/23 00:00  30/11/23 08:40      2        ETRA
# 2  16/01/24 10:41  30/11/23 00:00  30/11/23 08:53      2        ETRA
# 3  16/01/24 10:41  30/11/23 00:00  30/11/23 09:15      2        ETRA
# 4  16/01/24 10:41  30/11/23 00:00  30/11/23 09:30      2        ETRA
#
#   tipo_movimiento  tipo_movimiento_desc
# 0               1              DESCARGA
# 1               1              DESCARGA
# 2               1              DESCARGA
# 3               1              DESCARGA
# 4               1              DESCARGA
#
# [5 rows x 41 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222 entries, 0 to 1221
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pesada                 1222 non-null   int64
#  1   fecha_dia              1222 non-null   object
#  2   fecha                  1222 non-null   object
#  3   matricula_letra        1222 non-null   object
#  4   tipo_residuo           1222 non-null   int64
#  5   tipo_residuo_desc      1222 non-null   object
#  6   subtipo_residuo        1222 non-null   int64
#  7   subtipo_residuo_desc   1222 non-null   object
#  8   peso_neto              1222 non-null   int64
#  9   peso_bruto             1222 non-null   int64
#  10  tara                   1222 non-null   int64
#  11  balanza                1222 non-null   int64
#  12  medio_transp           1222 non-null   int64
#  13  medio_transp_desc      1222 non-null   object
#  14  trayecto               0 non-null      float64
#  15  trayecto_desc          0 non-null      float64
#  16  tipo_recorrido         0 non-null      float64
#  17  tipo_recorrido_desc    0 non-null      float64
#  18  tipo_volcado_desc      1222 non-null   object
#  19  nomenclatura_circuito  0 non-null      float64
#  20  municipio              0 non-null      float64
#  21  lugar_salida           0 non-null      float64
#  22  lugar_salida_desc      0 non-null      float64
#  23  permiso                0 non-null      float64
#  24  nro_permiso            394 non-null    float64
#  25  permiso_id             394 non-null    float64
#  26  tipo_permiso           394 non-null    float64
#  27  tipo_permiso_desc      394 non-null    object
#  28  peso_autorizado        0 non-null      float64
#  29  destino_volcado        1222 non-null   int64
#  30  destino_volcado_desc   1222 non-null   object
#  31  tipo_pesada            1222 non-null   int64
#  32  tipo_pesada_desc       1222 non-null   object
#  33  basura_propia          1222 non-null   object
#  34  fmod                   1222 non-null   object
#  35  viaje_fecha            785 non-null    object
#  36  fecha_tara             1222 non-null   object
#  37  sitio                  1222 non-null   int64
#  38  sitio_desc             1222 non-null   object
#  39  tipo_movimiento        1222 non-null   int64
#  40  tipo_movimiento_desc   1222 non-null   object
# dtypes: float64(13), int64(12), object(16)
# memory usage: 391.6+ KB
# np.int64(0)
