# %%
datos = {
    "objeto": [
        "almohadita",
        "jeringa",
        "anillitos",
        "lentes snowboard",
        "piezas random",
        "cuaderno",
        "cubo Rubik",
        "lapicera"
    ],

    "movimiento": [0, 1, 0, 0, 0, 1, 1, 0],
    "blando":     [1, 0, 0, 0, 0, 0, 0, 0],
    "flexible":   [1, 0, 0, 1, 1, 1, 0, 0],
    "plastico":   [0, 1, 1, 1, 1, 1, 1, 1],
    "metal":      [0, 0, 0, 0, 1, 0, 0, 1],
    "liso":       [0, 1, 1, 1, 0, 1, 1, 1]
}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(datos)

print(df)
# Out:
#              objeto  movimiento  blando  flexible  plastico  metal  liso
# 0        almohadita           0       1         1         0      0     0
# 1           jeringa           1       0         0         1      0     1
# 2         anillitos           0       0         0         1      0     1
# 3  lentes snowboard           0       0         1         1      0     1
# 4     piezas random           0       0         1         1      1     0
# 5          cuaderno           1       0         1         1      0     1
# 6        cubo Rubik           1       0         0         1      0     1
# 7          lapicera           0       0         0         1      1     1
